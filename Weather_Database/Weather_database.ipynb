# %%
# import dependenices
import pandas as pd
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 742

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
# Weather base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()

        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
#  Record 40 of Set 6 | cairns
# Processing Record 41 of Set 6 | dera din panah
# City not found. Skipping...
# Processing Record 42 of Set 6 | north bend
# Processing Record 43 of Set 6 | perwez
# Processing Record 44 of Set 6 | sergeyevka
# Processing Record 45 of Set 6 | porto nacional
# Processing Record 46 of Set 6 | santa marinella
# Processing Record 47 of Set 6 | yaan
# Processing Record 48 of Set 6 | honiara
# Processing Record 49 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 6 | pontianak
# Processing Record 1 of Set 7 | teguise
# Processing Record 2 of Set 7 | tual
# Processing Record 3 of Set 7 | coos bay
# Processing Record 4 of Set 7 | kodinsk
# Processing Record 5 of Set 7 | yar-sale
# Processing Record 6 of Set 7 | jalu
# Processing Record 7 of Set 7 | anloga
# Processing Record 8 of Set 7 | kaitangata
# Processing Record 9 of Set 7 | vostok
# Processing Record 10 of Set 7 | nuuk
# Processing Record 11 of Set 7 | puerto del rosario
# Processing Record 12 of Set 7 | nemuro
# Processing Record 13 of Set 7 | wewak
# Processing Record 14 of Set 7 | kintinku
# Processing Record 15 of Set 7 | bayanday
# Processing Record 16 of Set 7 | menongue
# Processing Record 17 of Set 7 | dukat
# Processing Record 18 of Set 7 | kodiak
# Processing Record 19 of Set 7 | isperih
# Processing Record 20 of Set 7 | forbes
# Processing Record 21 of Set 7 | saint-joseph
# Processing Record 22 of Set 7 | florianopolis
# Processing Record 23 of Set 7 | murgab
# Processing Record 24 of Set 7 | roches noires
# City not found. Skipping...
# Processing Record 25 of Set 7 | weligama
# Processing Record 26 of Set 7 | suntar
# Processing Record 27 of Set 7 | richards bay
# Processing Record 28 of Set 7 | dunedin
# Processing Record 29 of Set 7 | tongliao
# Processing Record 30 of Set 7 | concarneau
# Processing Record 31 of Set 7 | peniche
# Processing Record 32 of Set 7 | saint george
# Processing Record 33 of Set 7 | san cristobal
# Processing Record 34 of Set 7 | vasilkovo
# City not found. Skipping...
# Processing Record 35 of Set 7 | shalyhyne
# Processing Record 36 of Set 7 | westport
# Processing Record 37 of Set 7 | vestbygda
# City not found. Skipping...
# Processing Record 38 of Set 7 | gat
# Processing Record 39 of Set 7 | constitucion
# Processing Record 40 of Set 7 | riyadh
# Processing Record 41 of Set 7 | dingle
# Processing Record 42 of Set 7 | herat
# Processing Record 43 of Set 7 | lake havasu city
# Processing Record 44 of Set 7 | kurilsk
# Processing Record 45 of Set 7 | buala
# Processing Record 46 of Set 7 | kingisepp
# Processing Record 47 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 48 of Set 7 | ulaanbaatar
# Processing Record 49 of Set 7 | palmer
# Processing Record 50 of Set 7 | luau
# Processing Record 1 of Set 8 | lagoa
# Processing Record 2 of Set 8 | samana
# Processing Record 3 of Set 8 | poninka
# Processing Record 4 of Set 8 | stornoway
# Processing Record 5 of Set 8 | salalah
# Processing Record 6 of Set 8 | ixtapa
# Processing Record 7 of Set 8 | yamoussoukro
# Processing Record 8 of Set 8 | kusye-aleksandrovskiy
# City not found. Skipping...
# Processing Record 9 of Set 8 | santa maria del oro
# Processing Record 10 of Set 8 | ganzhou
# Processing Record 11 of Set 8 | guarapari
# Processing Record 12 of Set 8 | pozo colorado
# Processing Record 13 of Set 8 | labuhan
# Processing Record 14 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 8 | balimo
# City not found. Skipping...
# Processing Record 16 of Set 8 | natal
# Processing Record 17 of Set 8 | aleksandrovskiy zavod
# Processing Record 18 of Set 8 | dhing
# Processing Record 19 of Set 8 | sawakin
# Processing Record 20 of Set 8 | kill
# Processing Record 21 of Set 8 | asfi
# Processing Record 22 of Set 8 | rio grande
# Processing Record 23 of Set 8 | grand island
# Processing Record 24 of Set 8 | nzega
# Processing Record 25 of Set 8 | wanning
# Processing Record 26 of Set 8 | agua dulce
# Processing Record 27 of Set 8 | severo-kurilsk
# Processing Record 28 of Set 8 | ayagoz
# Processing Record 29 of Set 8 | chopinzinho
# Processing Record 30 of Set 8 | shetpe
# Processing Record 31 of Set 8 | alghero
# Processing Record 32 of Set 8 | aklavik
# Processing Record 33 of Set 8 | aitape
# Processing Record 34 of Set 8 | la ronge
# Processing Record 35 of Set 8 | alofi
# Processing Record 36 of Set 8 | upernavik
# Processing Record 37 of Set 8 | thomasville
# Processing Record 38 of Set 8 | nanortalik
# Processing Record 39 of Set 8 | boueni
# Processing Record 40 of Set 8 | la rioja
# Processing Record 41 of Set 8 | batagay
# Processing Record 42 of Set 8 | luderitz
# Processing Record 43 of Set 8 | vila
# Processing Record 44 of Set 8 | abaza
# Processing Record 45 of Set 8 | matamoros
# Processing Record 46 of Set 8 | vanavara
# Processing Record 47 of Set 8 | taoudenni
# Processing Record 48 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 8 | aguazul
# Processing Record 50 of Set 8 | reconquista
# Processing Record 1 of Set 9 | karla
# Processing Record 2 of Set 9 | deputatskiy
# Processing Record 3 of Set 9 | shimanovsk
# Processing Record 4 of Set 9 | zemio
# Processing Record 5 of Set 9 | broken hill
# Processing Record 6 of Set 9 | lulea
# Processing Record 7 of Set 9 | salinopolis
# Processing Record 8 of Set 9 | santa isabel do rio negro
# Processing Record 9 of Set 9 | mogok
# Processing Record 10 of Set 9 | broome
# Processing Record 11 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 12 of Set 9 | abu kamal
# Processing Record 13 of Set 9 | sitka
# Processing Record 14 of Set 9 | conceicao da barra
# Processing Record 15 of Set 9 | wroclaw
# Processing Record 16 of Set 9 | saint anthony
# Processing Record 17 of Set 9 | puerto carreno
# Processing Record 18 of Set 9 | deer lake
# Processing Record 19 of Set 9 | korla
# Processing Record 20 of Set 9 | vallenar
# Processing Record 21 of Set 9 | eureka
# Processing Record 22 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 23 of Set 9 | martapura
# Processing Record 24 of Set 9 | rosarito
# Processing Record 25 of Set 9 | san matias
# Processing Record 26 of Set 9 | rawson
# Processing Record 27 of Set 9 | afmadu
# City not found. Skipping...
# Processing Record 28 of Set 9 | snyder
# Processing Record 29 of Set 9 | taltal
# Processing Record 30 of Set 9 | kerteh
# City not found. Skipping...
# Processing Record 31 of Set 9 | marawi
# Processing Record 32 of Set 9 | birao
# Processing Record 33 of Set 9 | margate
# Processing Record 34 of Set 9 | sao bernardo
# Processing Record 35 of Set 9 | wynyard
# Processing Record 36 of Set 9 | pringsewu
# Processing Record 37 of Set 9 | klaksvik
# Processing Record 38 of Set 9 | kondinskoye
# Processing Record 39 of Set 9 | kalga
# Processing Record 40 of Set 9 | kizema
# Processing Record 41 of Set 9 | hit
# Processing Record 42 of Set 9 | necochea
# Processing Record 43 of Set 9 | nouadhibou
# Processing Record 44 of Set 9 | escanaba
# Processing Record 45 of Set 9 | superior
# Processing Record 46 of Set 9 | lampang
# Processing Record 47 of Set 9 | hami
# Processing Record 48 of Set 9 | lasa
# Processing Record 49 of Set 9 | laguna
# Processing Record 50 of Set 9 | gibsons
# Processing Record 1 of Set 10 | panguna
# Processing Record 2 of Set 10 | grindavik
# Processing Record 3 of Set 10 | preobrazheniye
# Processing Record 4 of Set 10 | poum
# Processing Record 5 of Set 10 | san jeronimo
# Processing Record 6 of Set 10 | shahreza
# Processing Record 7 of Set 10 | kuching
# Processing Record 8 of Set 10 | noumea
# Processing Record 9 of Set 10 | asilah
# Processing Record 10 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 11 of Set 10 | sena madureira
# Processing Record 12 of Set 10 | bestobe
# Processing Record 13 of Set 10 | chapais
# Processing Record 14 of Set 10 | destin
# Processing Record 15 of Set 10 | nyurba
# Processing Record 16 of Set 10 | victoria
# Processing Record 17 of Set 10 | turinsk
# Processing Record 18 of Set 10 | zhangye
# Processing Record 19 of Set 10 | puerto madero
# Processing Record 20 of Set 10 | bemidji
# Processing Record 21 of Set 10 | bumba
# Processing Record 22 of Set 10 | sandwick
# Processing Record 23 of Set 10 | dzilam gonzalez
# Processing Record 24 of Set 10 | kaeo
# Processing Record 25 of Set 10 | belmonte
# Processing Record 26 of Set 10 | cozieni
# Processing Record 27 of Set 10 | price
# Processing Record 28 of Set 10 | malatya
# Processing Record 29 of Set 10 | ferme-neuve
# Processing Record 30 of Set 10 | barra
# Processing Record 31 of Set 10 | eyl
# Processing Record 32 of Set 10 | bolobo
# Processing Record 33 of Set 10 | pontes e lacerda
# Processing Record 34 of Set 10 | beringovskiy
# Processing Record 35 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 36 of Set 10 | sijunjung
# Processing Record 37 of Set 10 | te anau
# Processing Record 38 of Set 10 | isangel
# Processing Record 39 of Set 10 | acajutla
# Processing Record 40 of Set 10 | cascais
# Processing Record 41 of Set 10 | tuatapere
# Processing Record 42 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 43 of Set 10 | skibbereen
# Processing Record 44 of Set 10 | secunda
# Processing Record 45 of Set 10 | kathmandu
# Processing Record 46 of Set 10 | sao felix do xingu
# Processing Record 47 of Set 10 | cayenne
# Processing Record 48 of Set 10 | ritchie
# Processing Record 49 of Set 10 | guane
# Processing Record 50 of Set 10 | turayf
# Processing Record 1 of Set 11 | tommot
# Processing Record 2 of Set 11 | kathu
# Processing Record 3 of Set 11 | tazmalt
# Processing Record 4 of Set 11 | coahuayana
# Processing Record 5 of Set 11 | qibili
# City not found. Skipping...
# Processing Record 6 of Set 11 | raymondville
# Processing Record 7 of Set 11 | makakilo city
# Processing Record 8 of Set 11 | zhigansk
# Processing Record 9 of Set 11 | kaitong
# Processing Record 10 of Set 11 | bressuire
# Processing Record 11 of Set 11 | san ramon
# Processing Record 12 of Set 11 | tezu
# Processing Record 13 of Set 11 | fortuna
# Processing Record 14 of Set 11 | saipipi
# City not found. Skipping...
# Processing Record 15 of Set 11 | srednekolymsk
# Processing Record 16 of Set 11 | januaria
# Processing Record 17 of Set 11 | talnakh
# Processing Record 18 of Set 11 | manoel urbano
# Processing Record 19 of Set 11 | puerto el triunfo
# Processing Record 20 of Set 11 | rockhampton
# Processing Record 21 of Set 11 | lodja
# Processing Record 22 of Set 11 | soyo
# Processing Record 23 of Set 11 | miles city
# Processing Record 24 of Set 11 | kushiro
# Processing Record 25 of Set 11 | teeli
# Processing Record 26 of Set 11 | saurimo
# Processing Record 27 of Set 11 | eregli
# Processing Record 28 of Set 11 | portland
# Processing Record 29 of Set 11 | mahendranagar
# Processing Record 30 of Set 11 | bellevue
# Processing Record 31 of Set 11 | solnechnyy
# Processing Record 32 of Set 11 | del rio
# Processing Record 33 of Set 11 | madang
# Processing Record 34 of Set 11 | provideniya
# Processing Record 35 of Set 11 | nieuw nickerie
# Processing Record 36 of Set 11 | faya
# Processing Record 37 of Set 11 | olafsvik
# Processing Record 38 of Set 11 | fairbanks
# Processing Record 39 of Set 11 | hambantota
# Processing Record 40 of Set 11 | coquimbo
# Processing Record 41 of Set 11 | baghdad
# Processing Record 42 of Set 11 | ville-marie
# Processing Record 43 of Set 11 | moose factory
# Processing Record 44 of Set 11 | baruun-urt
# Processing Record 45 of Set 11 | tungkang
# City not found. Skipping...
# Processing Record 46 of Set 11 | akureyri
# Processing Record 47 of Set 11 | vieste
# Processing Record 48 of Set 11 | tombouctou
# Processing Record 49 of Set 11 | padang
# Processing Record 50 of Set 11 | namibe
# Processing Record 1 of Set 12 | bakel
# Processing Record 2 of Set 12 | serenje
# Processing Record 3 of Set 12 | caaguazu
# Processing Record 4 of Set 12 | nabire
# Processing Record 5 of Set 12 | florence
# Processing Record 6 of Set 12 | shiyan
# Processing Record 7 of Set 12 | meulaboh
# Processing Record 8 of Set 12 | axim
# Processing Record 9 of Set 12 | mersing
# Processing Record 10 of Set 12 | krasnyy chikoy
# Processing Record 11 of Set 12 | saint-leu
# Processing Record 12 of Set 12 | ternate
# Processing Record 13 of Set 12 | abu dhabi
# Processing Record 14 of Set 12 | umm lajj
# Processing Record 15 of Set 12 | kamaishi
# Processing Record 16 of Set 12 | kununurra
# Processing Record 17 of Set 12 | vicuna
# Processing Record 18 of Set 12 | qeshm
# Processing Record 19 of Set 12 | okhotsk
# Processing Record 20 of Set 12 | sesheke
# Processing Record 21 of Set 12 | saint-pierre
# Processing Record 22 of Set 12 | romanovskaya
# Processing Record 23 of Set 12 | kavaratti
# Processing Record 24 of Set 12 | aviles
# Processing Record 25 of Set 12 | kieta
# Processing Record 26 of Set 12 | anavra
# Processing Record 27 of Set 12 | talaya
# Processing Record 28 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 12 | naberera
# Processing Record 30 of Set 12 | khromtau
# Processing Record 31 of Set 12 | huarmey
# Processing Record 32 of Set 12 | hamilton
# Processing Record 33 of Set 12 | kandrian
# Processing Record 34 of Set 12 | acapulco
# Processing Record 35 of Set 12 | susehri
# Processing Record 36 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 37 of Set 12 | seymchan
# Processing Record 38 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 39 of Set 12 | charleston
# Processing Record 40 of Set 12 | maghama
# City not found. Skipping...
# Processing Record 41 of Set 12 | arefu
# Processing Record 42 of Set 12 | fostoria
# Processing Record 43 of Set 12 | ocampo
# Processing Record 44 of Set 12 | simoes
# Processing Record 45 of Set 12 | roanoke rapids
# Processing Record 46 of Set 12 | tenenkou
# Processing Record 47 of Set 12 | mexico
# Processing Record 48 of Set 12 | bantry
# Processing Record 49 of Set 12 | huntington
# Processing Record 50 of Set 12 | geraldton
# Processing Record 1 of Set 13 | agogo
# Processing Record 2 of Set 13 | hobyo
# Processing Record 3 of Set 13 | kudahuvadhoo
# Processing Record 4 of Set 13 | goksun
# Processing Record 5 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 6 of Set 13 | kirkwood
# Processing Record 7 of Set 13 | new plymouth
# Processing Record 8 of Set 13 | yarim
# Processing Record 9 of Set 13 | staryy nadym
# Processing Record 10 of Set 13 | madison heights
# Processing Record 11 of Set 13 | chegdomyn
# Processing Record 12 of Set 13 | tynda
# Processing Record 13 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 14 of Set 13 | lufkin
# Processing Record 15 of Set 13 | rajpura
# Processing Record 16 of Set 13 | lixourion
# Processing Record 17 of Set 13 | abha
# Processing Record 18 of Set 13 | yarmouth
# Processing Record 19 of Set 13 | terrace bay
# Processing Record 20 of Set 13 | kulhudhuffushi
# Processing Record 21 of Set 13 | cody
# Processing Record 22 of Set 13 | marseille
# Processing Record 23 of Set 13 | tecpan
# Processing Record 24 of Set 13 | port moresby
# Processing Record 25 of Set 13 | puerto leguizamo
# Processing Record 26 of Set 13 | phu khieo
# City not found. Skipping...
# Processing Record 27 of Set 13 | lorengau
# Processing Record 28 of Set 13 | tomatlan
# Processing Record 29 of Set 13 | yining
# Processing Record 30 of Set 13 | bolonchen
# City not found. Skipping...
# Processing Record 31 of Set 13 | ambilobe
# Processing Record 32 of Set 13 | kindersley
# Processing Record 33 of Set 13 | hundorp
# Processing Record 34 of Set 13 | ust-kuyga
# Processing Record 35 of Set 13 | ilebo
# Processing Record 36 of Set 13 | batamshinskiy
# Processing Record 37 of Set 13 | flinders
# Processing Record 38 of Set 13 | prudentopolis
# Processing Record 39 of Set 13 | samarai
# Processing Record 40 of Set 13 | hua hin
# Processing Record 41 of Set 13 | playas
# Processing Record 42 of Set 13 | manaus
# Processing Record 43 of Set 13 | revelstoke
# Processing Record 44 of Set 13 | sitrah
# Processing Record 45 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 46 of Set 13 | husavik
# Processing Record 47 of Set 13 | hasaki
# Processing Record 48 of Set 13 | ventspils
# Processing Record 49 of Set 13 | katsuura
# Processing Record 50 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 1 of Set 14 | norsup
# Processing Record 2 of Set 14 | huilong
# Processing Record 3 of Set 14 | kiama
# Processing Record 4 of Set 14 | biltine
# Processing Record 5 of Set 14 | nizip
# Processing Record 6 of Set 14 | aguimes
# Processing Record 7 of Set 14 | leshukonskoye
# Processing Record 8 of Set 14 | buraydah
# Processing Record 9 of Set 14 | dedza
# Processing Record 10 of Set 14 | bennettsville
# Processing Record 11 of Set 14 | tarakan
# Processing Record 12 of Set 14 | shelburne
# Processing Record 13 of Set 14 | cape girardeau
# Processing Record 14 of Set 14 | flin flon
# Processing Record 15 of Set 14 | ajdabiya
# Processing Record 16 of Set 14 | sampang
# Processing Record 17 of Set 14 | seybaplaya
# Processing Record 18 of Set 14 | andapa
# Processing Record 19 of Set 14 | bonthe
# Processing Record 20 of Set 14 | sakaiminato
# Processing Record 21 of Set 14 | zhongshu
# Processing Record 22 of Set 14 | mumford
# Processing Record 23 of Set 14 | altay
# Processing Record 24 of Set 14 | nanton
# Processing Record 25 of Set 14 | vardo
# Processing Record 26 of Set 14 | charlottesville
# Processing Record 27 of Set 14 | jinchang
# Processing Record 28 of Set 14 | baturaja
# Processing Record 29 of Set 14 | praia da vitoria
# Processing Record 30 of Set 14 | astana
# Processing Record 31 of Set 14 | torrington
# Processing Record 32 of Set 14 | meridian
# Processing Record 33 of Set 14 | loncoche
# Processing Record 34 of Set 14 | kosino
# Processing Record 35 of Set 14 | carikar
# City not found. Skipping...
# Processing Record 36 of Set 14 | kampot
# Processing Record 37 of Set 14 | nicoya
# Processing Record 38 of Set 14 | sakakah
# Processing Record 39 of Set 14 | isla mujeres
# Processing Record 40 of Set 14 | moyale
# Processing Record 41 of Set 14 | biloela
# Processing Record 42 of Set 14 | port macquarie
# Processing Record 43 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 44 of Set 14 | amursk
# Processing Record 45 of Set 14 | livingstonia
# Processing Record 46 of Set 14 | clarence town
# Processing Record 47 of Set 14 | cowra
# Processing Record 48 of Set 14 | tejupilco
# City not found. Skipping...
# Processing Record 49 of Set 14 | bungu
# Processing Record 50 of Set 14 | milkovo
# Processing Record 1 of Set 15 | sobolevo
# Processing Record 2 of Set 15 | south valley
# Processing Record 3 of Set 15 | skalistyy
# City not found. Skipping...
# Processing Record 4 of Set 15 | muravlenko
# Processing Record 5 of Set 15 | umm kaddadah
# Processing Record 6 of Set 15 | pundaguitan
# Processing Record 7 of Set 15 | kabompo
# Processing Record 8 of Set 15 | qaqortoq
# Processing Record 9 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 10 of Set 15 | meadow lake
# Processing Record 11 of Set 15 | rio gallegos
# Processing Record 12 of Set 15 | vung tau
# Processing Record 13 of Set 15 | malartic
# Processing Record 14 of Set 15 | amapa
# Processing Record 15 of Set 15 | luena
# Processing Record 16 of Set 15 | arandis
# Processing Record 17 of Set 15 | toora-khem
# Processing Record 18 of Set 15 | fez
# Processing Record 19 of Set 15 | baiyin
# Processing Record 20 of Set 15 | san juan
# Processing Record 21 of Set 15 | ust-tsilma
# Processing Record 22 of Set 15 | porto belo
# Processing Record 23 of Set 15 | felidhoo
# City not found. Skipping...
# Processing Record 24 of Set 15 | kerema
# Processing Record 25 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 26 of Set 15 | egvekinot
# Processing Record 27 of Set 15 | nampula
# Processing Record 28 of Set 15 | plettenberg bay
# Processing Record 29 of Set 15 | teahupoo
# Processing Record 30 of Set 15 | arica
# Processing Record 31 of Set 15 | tabuk
# Processing Record 32 of Set 15 | avera
# Processing Record 33 of Set 15 | dolores
# Processing Record 34 of Set 15 | ascope
# Processing Record 35 of Set 15 | leh
# Processing Record 36 of Set 15 | gasa
# Processing Record 37 of Set 15 | katangli
# Processing Record 38 of Set 15 | sale
# Processing Record 39 of Set 15 | tiznit
# Processing Record 40 of Set 15 | los llanos de aridane
# Processing Record 41 of Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 42 of Set 15 | bath
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create DF and visually inspect DF
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Bonfim      BR   3.0833  -59.9500     82.71        76          66
# 1           Airai      TL  -8.9266  125.4092     56.01        62          99
# 2    Punta Arenas      CL -53.1500  -70.9167     37.51        93          75
# 3             Oia      PT  40.5426   -8.5386     68.45        75           2
# 4     New Norfolk      AU -42.7826  147.0587     49.57        71          74
# 5       Zavetnoye      RU  47.1194   43.8903     80.64        43          45
# 6           Gamba      GA  -2.6500   10.0000     70.36        90          74
# 7  Saint-Philippe      RE -21.3585   55.7679     69.39        77          40
# 8         Kavieng      PG  -2.5744  150.7967     82.51        78          98
# 9            Ayan      RU  56.4500  138.1667     62.94        66          94
#
#    Wind Speed Current Description
# 0        6.26       broken clouds
# 1        2.51     overcast clouds
# 2        8.05          light rain
# 3        3.06           clear sky
# 4        3.00       broken clouds
# 5        6.51    scattered clouds
# 6        4.27       broken clouds
# 7       11.41    scattered clouds
# 8       12.39          light rain
# 9       13.42     overcast clouds

# %%
city_data_df.to_csv("WeatherPy_Database.csv")
